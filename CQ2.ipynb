# %% [markdown]
# <a href="https://colab.research.google.com/github/ChillyPNDA/PROGCOM-A/blob/main/CQ2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![FOTOO CHECKIO.png](data:image/png;base64,...)
